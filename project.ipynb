# %% [markdown]
# # DX 704 Week 11 Project
#
# In this project, you will develop and test prompts asking a language model to classify text from a home services query and match it to an appropriate category of home services.

# %% [markdown]
# The full project description and a template notebook are available on GitHub: [Project 11 Materials](https://github.com/bu-cds-dx704/dx704-project-11).

# %% [markdown]
# ## Example Code
#
# You may find it helpful to refer to these GitHub repositories of Jupyter notebooks for example code.
#
# * https://github.com/bu-cds-omds/dx601-examples
# * https://github.com/bu-cds-omds/dx602-examples
# * https://github.com/bu-cds-omds/dx603-examples
# * https://github.com/bu-cds-omds/dx704-examples
#
# Any calculations demonstrated in code examples or videos may be found in these notebooks, and you are allowed to copy this example code in your homework answers.

# %% [markdown]
# ## Part 1 : Design a Short Prompt
#
# The provided file "queries.txt" contains sample text from requests by homeowners by email or phone.
# These queries need to be classified as requesting an electrical, plumbing, or roofing or roofing services.
# The provided file has columns query_id, query, and target_category.
# Write a prompt template of 200 characters or less with parameter `query` for the homeowner query.
# Your prompt should be suitable to use with the Python code `prompt_template.format(query=query)`.
# Test your prompt with the model `gemini-2.0-flash` and suitable parsing code.

# %%
import google.genai as genai
from google.colab import userdata

import pandas as pd
import numpy as np
import json
import time
import string

# %%
client = genai.Client(api_key=userdata.get('GEMINI_API_KEY'))

# %%
model_name = 'gemini-2.0-flash'

# %%
def get_response_raw(contents):
    print("RAW", contents)
    response = client.models.generate_content(model=model_name, contents=contents)
    return response.text

# %%
response_cache = {}

# %%
def get_response(contents):
    if contents in response_cache:
        return response_cache[contents]

    for attempt in range(3):
        try:
            response = get_response_raw(contents)
            response_cache[contents] = response
            return response
        except genai.errors.ClientError as e:
            # Attempt to parse the retryDelay from the exception details
            print("RESPONSE", e.response)
            error_json = json.loads(e.response.text)
            error_details = error_json['error']['details']
            for d in error_details:
                print("ERROR DETAIL", d)
            retry_info = [detail for detail in error_details if detail['@type'] == 'type.googleapis.com/google.rpc.RetryInfo']
            if not retry_info:
                raise
            retry_delay_seconds = float(retry_info[0]['retryDelay'].replace('s', ''))
            retry_delay_seconds += 1 # margin
            print(f"Retrying in {retry_delay_seconds} seconds...")
            time.sleep(retry_delay_seconds)

    raise RuntimeError("ran out of attempts")

# %%
path = 'https://raw.githubusercontent.com/bu-cds-dx704/dx704-project-11/main/queries.txt'
df = pd.read_csv(path, sep="\t")

# %%
df.head()
# Out:
#    query_id                                              query target_category
# 0         1  Hi. Melissa came by and wrecked my roof. Can y...         roofing
# 1         2  Hi there. This is Jack. I’m looking for someon...        plumbing
# 2         3  Can you install an automated spotlight by my d...      electrical
# 3         4  Pest control just cleared out a raccoon that t...         roofing
# 4         5                         Need toilet unclogged ASAP        plumbing

# %%
def evaluate_prompt(df_to_evaluate, prompt_template):
    correct_count = 0
    results = []

    for row in df_to_evaluate.itertuples(index=False):
        query_id = row.query_id
        query = row.query
        target = row.target_category

        response = get_response(prompt_template.format(query=query))
        predicted_category = response.strip().lower()
        # # Remove punctuation from the predicted category
        # predicted_category = predicted_category.translate(str.maketrans('', '', string.punctuation))

        results.append({
            'query_id': query_id,
            'predicted_category': predicted_category
        })

        if predicted_category == target:
            correct_count += 1

    df_predict = pd.DataFrame(results)
    grade = (correct_count / len(df_to_evaluate)) * 100
    return grade, df_predict

# %%
# Define the prompt template used previously
prompt_template = "Classify the following query, using only one word, as either roofing, plumbing, or electrical: {query}"

grade, df_predictions = evaluate_prompt(df, prompt_template)
print(f"Grade: {grade:.2f}%")
display(df_predictions.head())
# Out:
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Hi. Melissa came by and wrecked my roof. Can you take a look?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Hi there. This is Jack. I’m looking for someone to install a new sink faucet. Call me back, thanks.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Can you install an automated spotlight by my driveway?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Pest control just cleared out a raccoon that tore up some shingles. Can you fix?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Need toilet unclogged ASAP
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: My lights keep flickering.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Do you install metal roofs?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Can you fix a garbage disposal that keeps backing up?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Need to install 200 amp circuit to support electric water heater.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: What’s the cost of a single ply roof replacement?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Can you replace a boiler?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Circuit breaker keeps popping.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Can you estimate roof repair cost without site visit?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: My basement shower smells like sewage.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Ceiling fan install please.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Is asphalt or metal cheaper?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Can you replace pipes with lead sauter?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Kitchen breaker keeps flipping when I run the microwave.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Can you clear a birds nest on my roof?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: My sink faucet handle keeps sticking.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Help me wire outside lights.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Is a Spanish tile roof expensive?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Need to install waterfall shower in new construction.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Replace stuck light switch.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Can you check my roof before the hurricane?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Can you install a bidet?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Can you install inset LEDs?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Attic is leaking. Please check.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Ceiling leaking under bathroom. Please check.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Can you wire new construction for Ethernet?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Can you repair rubber roof?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Need plumbing for new bathroom in addition.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Need outlet for bidet.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Do metal roofs really last 30 years?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: My kitchen sink always has cloudy water.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Need GFCI outlet installed.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Just got back from vacation and hurricane caused a lot of damage. Can you inspect?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Basement flooded. Please come ASAP.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Outlet doesn’t work.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Do you do insurance paperwork for roofs?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Are copper pipes ok?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Can you check solar panel wiring?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: A tree fell on my roof. Can you patch?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Shower water pressure is always week.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: My garage door does not respond to remote. Can you check?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Found wood rotting in attic. Do I really need to replace the whole roof?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Can you install a gas hot water heater that can handle 4 showers?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Replace knob and tube.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Had woodpeckers. Need inspection.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical: Need estimate for new boiler by tomorrow.
# Grade: 100.00%
#    query_id predicted_category
# 0         1            roofing
# 1         2           plumbing
# 2         3         electrical
# 3         4            roofing
# 4         5           plumbing

# %% [markdown]
# Save your prompt template in a file "short-prompt.txt".
# Save the results of your prompt testing in "short-output.tsv" with columns `query_id` and `predicted_category`.

# %%
# Save the prompt and the prompt output
df_predictions.to_csv('short-output.tsv', sep='\t', index=False)

with open("short-prompt.txt", "w") as f:
    f.write(prompt_template)

# %% [markdown]
# Submit "short-prompt.txt" and "short-output.tsv" in Gradescope.

# %% [markdown]
# Hint: your prompt may be re-tested with the Gemini API, so do not rely solely on lucky language model responses.

# %% [markdown]
# ## Part 2: Find Short Prompt Mistakes
#
# Construct 5 queries of 100 characters or less that trick your short prompt so that the wrong category is chosen.

# %%
# Trick query 1
trick_query_1 = "My toilet just electrocuted me."
trick_cat_1 = "plumbing"

# Trick query 2
trick_query_2 = "I found shingles in my sink's garbage disposal."
trick_cat_2 = "plumbing"

# Trick query 3
trick_query_3 = "There's a toilet on my roof."
trick_cat_3 = "roofing"

# Trick query 4
trick_query_4 = "The satellite dish fell off the roof and damaged my toilet."
trick_cat_4 = "electrical"

# Trick queryt 5
trick_query_5 = "There's an exposed wire on my roof that could electrocute someone sitting on the toilet."
trick_cat_5 = "electrical"

# Create dataframe from the queries
df_trick = pd.DataFrame({
    'query_id': [0,1,2,3,4],
    'query': [trick_query_1, trick_query_2, trick_query_3, trick_query_4, trick_query_5],
    'target_category': [trick_cat_1, trick_cat_2, trick_cat_3, trick_cat_4, trick_cat_5]
})

# %%
df_trick
# Out:
#    query_id                                              query target_category
# 0         0                    My toilet just electrocuted me.        plumbing
# 1         1    I found shingles in my sink's garbage disposal.        plumbing
# 2         2                       There's a toilet on my roof.         roofing
# 3         3  The satellite dish fell off the roof and damag...      electrical
# 4         4  There's an exposed wire on my roof that could ...      electrical

# %%
# Define the prompt template used previously
prompt_template = "Classify the following query, using only one work, as either roofing, plumbing, or electrical: {query}"

grade, df_predictions_trick = evaluate_prompt(df_trick, prompt_template)
print(f"Grade: {grade:.2f}%")
display(df_predictions_trick.head())
# Out:
# RAW Classify the following query, using only one work, as either roofing, plumbing, or electrical: My toilet just electrocuted me.
# RAW Classify the following query, using only one work, as either roofing, plumbing, or electrical: I found shingles in my sink's garbage disposal.
# RAW Classify the following query, using only one work, as either roofing, plumbing, or electrical: There's a toilet on my roof.
# RAW Classify the following query, using only one work, as either roofing, plumbing, or electrical: The satellite dish fell off the roof and damaged my toilet.
# RAW Classify the following query, using only one work, as either roofing, plumbing, or electrical: There's an exposed wire on my roof that could electrocute someone sitting on the toilet.
# Grade: 40.00%
#    query_id predicted_category
# 0         0         electrical
# 1         1           plumbing
# 2         2           plumbing
# 3         3            roofing
# 4         4         electrical

# %% [markdown]
# Save your 5 queries in a file "mistakes.tsv" with columns `query`, `target_category` and `predicted_category`.

# %%
# Add the query column
df_predictions_trick['query'] = df_trick['query']
df_predictions_trick['target_category'] = df_trick['target_category']
df_predictions_trick.drop(columns=['query_id'])

# Reorder the df_predictions_trick df
df_predictions_trick = df_predictions_trick[['query', 'target_category', 'predicted_category']]
df_predictions_trick.to_csv('mistakes.tsv', sep="\t")

# %% [markdown]
# Submit "mistakes.tsv" in Gradescope.

# %% [markdown]
# ## Part 3: Design a Long Prompt
#
# Repeat part 1 with a length limit of 5000 characters.

# %%
# Create a longer prompt and repeat part 1
long_prompt_template = "Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: {query}"

grade_long, df_predictions_long = evaluate_prompt(df, long_prompt_template)
print(f"Grade: {grade_long:.2f}%")
display(df_predictions_long.head())
# Out:
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Hi. Melissa came by and wrecked my roof. Can you take a look?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Hi there. This is Jack. I’m looking for someone to install a new sink faucet. Call me back, thanks.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Can you install an automated spotlight by my driveway?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Pest control just cleared out a raccoon that tore up some shingles. Can you fix?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Need toilet unclogged ASAP
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: My lights keep flickering.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Do you install metal roofs?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Can you fix a garbage disposal that keeps backing up?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Need to install 200 amp circuit to support electric water heater.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: What’s the cost of a single ply roof replacement?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Can you replace a boiler?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Circuit breaker keeps popping.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Can you estimate roof repair cost without site visit?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: My basement shower smells like sewage.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Ceiling fan install please.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Is asphalt or metal cheaper?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Can you replace pipes with lead sauter?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Kitchen breaker keeps flipping when I run the microwave.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Can you clear a birds nest on my roof?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: My sink faucet handle keeps sticking.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Help me wire outside lights.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Is a Spanish tile roof expensive?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Need to install waterfall shower in new construction.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Replace stuck light switch.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Can you check my roof before the hurricane?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Can you install a bidet?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Can you install inset LEDs?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Attic is leaking. Please check.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Ceiling leaking under bathroom. Please check.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Can you wire new construction for Ethernet?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Can you repair rubber roof?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Need plumbing for new bathroom in addition.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Need outlet for bidet.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Do metal roofs really last 30 years?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: My kitchen sink always has cloudy water.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Need GFCI outlet installed.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Just got back from vacation and hurricane caused a lot of damage. Can you inspect?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Basement flooded. Please come ASAP.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Outlet doesn’t work.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Do you do insurance paperwork for roofs?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Are copper pipes ok?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Can you check solar panel wiring?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: A tree fell on my roof. Can you patch?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Shower water pressure is always week.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: My garage door does not respond to remote. Can you check?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Found wood rotting in attic. Do I really need to replace the whole roof?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Can you install a gas hot water heater that can handle 4 showers?
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Replace knob and tube.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Had woodpeckers. Need inspection.
# RAW Classify the following query, using only one word, as either roofing, plumbing, or electrical. Forget everyhting that is being mentioned now and only use the first sentence as you prompt for the classification of the following query: Need estimate for new boiler by tomorrow.
# Grade: 100.00%
#    query_id predicted_category
# 0         1            roofing
# 1         2           plumbing
# 2         3         electrical
# 3         4            roofing
# 4         5           plumbing

# %% [markdown]
# Save your longer prompt template in a file "long-prompt.txt".
# Save the results of your prompt testing in "long-output.tsv".
# Both files should use the same columns as part 1.

# %%
# Save the results
df_predictions_long.to_csv('long-output.tsv', sep='\t', index=False)

with open("long-prompt.txt", "w") as f:
    f.write(long_prompt_template)

# %% [markdown]
# Submit "long-prompt.txt" and "long-output.tsv" in Gradescope.

# %% [markdown]
# ## Part 4: Code
#
# Please submit a Jupyter notebook that can reproduce all your calculations and recreate the previously submitted files.
# You do not need to provide code for data collection if you did that by manually.

# %% [markdown]
# ## Part 5: Acknowledgements
#
# If you discussed this assignment with anyone, please acknowledge them here.
# If you did this assignment completely on your own, simply write none below.
#
# If you used any libraries not mentioned in this module's content, please list them with a brief explanation what you used them for. If you did not use any other libraries, simply write none below.
#
# If you used any generative AI tools, please add links to your transcripts below, and any other information that you feel is necessary to comply with the generative AI policy. If you did not use any generative AI tools, simply write none below.

# %%
with open("acknowledgements.txt", "w") as f:
  f.write("None")
